# %% [markdown]
# # 📘 Análisis Educación y Pobreza – Notebook Automático
# Este notebook carga los datos combinados, analiza correlaciones y genera algunos insights iniciales.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

data_path = '../data/merged_unicef_worldbank.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#                            country  year  poverty_rate country_name  \
# 0   {'id': 'BJ', 'value': 'Benin'}  2018          37.2        Benin
# 1   {'id': 'BJ', 'value': 'Benin'}  2018          37.2        Benin
# 2   {'id': 'BJ', 'value': 'Benin'}  2018          37.2        Benin
# 3   {'id': 'BJ', 'value': 'Benin'}  2018          37.2        Benin
# 4  {'id': 'BT', 'value': 'Bhutan'}  2012           3.6       Bhutan
#
#   country_code  Unnamed: 0  school_attendance
# 0          BEN          60          48.099998
# 1          BEN         298          68.300003
# 2          BEN         536          30.400000
# 3          BEN         774          11.800000
# 4          BTN         299          95.199997

# %%
df.describe()
# Out:
#               year  poverty_rate  Unnamed: 0  school_attendance
# count    17.000000     17.000000   17.000000          17.000000
# mean   2016.705882     42.729412  483.470588          47.221605
# std       1.571810     25.085897  277.255775          29.708794
# min    2012.000000      3.600000   60.000000           7.800000
# 25%    2016.000000     11.700000  298.000000          19.400000
# 50%    2016.000000     37.200000  468.000000          48.099998
# 75%    2018.000000     60.100000  706.000000          68.300003
# max    2018.000000     71.700000  944.000000          95.199997

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[['poverty_rate','school_attendance']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlación pobreza vs asistencia escolar')
plt.show()
